# %% [markdown]
# #Theory Questions:

# %% [markdown]
# **1. What is the difference between a function and a method in Python?**
#
# Function: A block of code that performs a task and is not tied to an object.
#
# Method: A function that is associated with an object.
#
#
# **Example:**

# %%
def greet():           # Function
    print("Hello")

"world".upper()        # Method (called on a string object)
# Out:
# 'WORLD'

# %% [markdown]
# **2. Explain the concept of function arguments and parameters in Python.**
#
# Parameters: Variables listed in the function definition.
#
# Arguments: Values passed to the function during the call.
#
# **Example:**

# %%
def add(a, b):         # a and b are parameters
    return a + b

add(3, 5)              # 3 and 5 are arguments
# Out:
# 8

# %% [markdown]
# **3. What are the different ways to define and call a function in Python?**
#
# **Define** -using def or lambda
#
# **Call**- by using the function name followed by parentheses

# %%
def square(x):         # using def
    return x * x

sq = lambda x: x*x     # using lambda

print(square(4))
print(sq(5))
# Out:
# 16
# 25

# %% [markdown]
# **4. What is the purpose of the return statement in a Python function?**
#
# It ends the function execution and optionally sends back a value.

# %%
def multiply(x, y):
    return x * y

# %% [markdown]
# **5. What are iterators in Python and how do they differ from iterables?**
#
# **Iterable:** An object you can loop over (like list, tuple)
#
# **Iterator:** An object with __next__() and __iter__() methods

# %%
nums = [1, 2, 3]       # iterable
it = iter(nums)        # iterator
print(next(it))        # outputs 1
# Out:
# 1

# %% [markdown]
# **6. Explain the concept of generators in Python and how they are defined.**
#
# :Generators yield values one by one using the yield keyword.
#
# :They are memory-efficient.

# %%
def count_up_to(n):
    for i in range(n):
        yield i

# %% [markdown]
# **7. What are the advantages of using generators over regular functions?**
#
# Lazy evaluation (values generated on demand)
#
# Lower memory usage
#
# Suitable for large datasets or infinite sequences

# %%
#Regular Function:
def get_numbers_list(n):
    result = []
    for i in range(n):
        result.append(i)
    return result

print(get_numbers_list(5))
# Out:
# [0, 1, 2, 3, 4]

# %%
#Generator Function:
def get_numbers_generator(n):
    for i in range(n):
        yield i

for num in get_numbers_generator(5):
    print(num)
# Out:
# 0
# 1
# 2
# 3
# 4

# %% [markdown]
# **8. What is a lambda function in Python and when is it typically used?**
#
# -Anonymous (unnamed) function defined using lambda
#
# -Used for short, simple functions

# %%
square = lambda x: x*x
print(square(6))
# Out:
# 36

# %% [markdown]
# **9. Explain the purpose and usage of the map() function in Python.**
#
# Applies a function to all items in an iterable.
#
# Example:

# %%
nums = [1, 2, 3]
squared = list(map(lambda x: x*x, nums))

# %% [markdown]
# **10. What is the difference between map(), reduce(), and filter() functions in Python?**
#
# | Function   | Purpose                            | Example                            |
# | ---------- | ---------------------------------- | ---------------------------------- |
# | `map()`    | Applies a function to each item    | `map(lambda x: x*2, [1, 2])`       |
# | `filter()` | Filters items based on a condition | `filter(lambda x: x>2, [1,2,3])`   |
# | `reduce()` | Applies function cumulatively      | `reduce(lambda x,y: x+y, [1,2,3])` |

# %% [markdown]
# **11. Using pen & paper, write the internal mechanism for sum operation using reduce() on this list: [47, 11, 42, 13]**
#
# Need to do this manually. But here's the logic:

# %%
from functools import reduce

nums = [47, 11, 42, 13]
sum_result = reduce(lambda x, y: x + y, nums)
print(sum_result)
# Out:
# 113

# %% [markdown]
# Step-by-step reduce working:
#
# Step 1: 47 + 11 → 58
#
# Step 2: 58 + 42 → 100
#
# Step 3: 100 + 13 → 113
#
# Result: 113

# %% [markdown]
# #Practical Questions:

# %% [markdown]
# **1. Write a Python function that takes a list of numbers as input and returns the sum of all even numbers in the list.**

# %%
def sum_even(numbers):
    return sum(num for num in numbers if num % 2 == 0)
    print(sum_even([1, 2, 3, 4, 5, 6])) #output 12

# %% [markdown]
# **2. Create a Python function that accepts a string and returns the reverse of that string.**

# %%
print(reverse_string("hello"))  # Output: "olleh"
# Out:
# olleh

# %% [markdown]
# **3. Implement a Python function that takes a list of integers and returns a new list containing the squares of each number.**

# %%
def square_list(numbers):
    return [num ** 2 for num in numbers]
    print (square_list([1, 2, 3, 4, 5]))  # Output: [1, 4, 9, 16, 25]

# %% [markdown]
# **4. Write a Python function that checks if a given number is prime or not from 1 to 200**

# %%
def is_prime(n):
    if n < 2:
        return False
    for i in range(2, int(n**0.5) + 1):
        if n % i == 0:
            return False
    return True

# Example: Check primes from 1 to 200
primes = [n for n in range(1, 201) if is_prime(n)]

# %% [markdown]
# **5. Create an iterator class in Python that generates the Fibonacci sequence up to a specified number of terms.**

# %%
class Fibonacci:
    def __init__(self, max_terms):
        self.max_terms = max_terms
        self.a, self.b = 0, 1
        self.count = 0

    def __iter__(self):
        return self

    def __next__(self):
        if self.count >= self.max_terms:
            raise StopIteration
        result = self.a
        self.a, self.b = self.b, self.a + self.b
        self.count += 1
        return result

# %% [markdown]
# **6. Write a generator function in Python that yields the powers of 2 up to a given exponent.**

# %%
def powers_of_two(n):
    for i in range(n + 1):
        yield 2 ** i

# %% [markdown]
# **7. Implement a generator function that reads a file line by line and yields each line as a string.**

# %%
def read_lines(filename):
    with open(filename, 'r') as file:
        for line in file:
            yield line.strip()

# %% [markdown]
# **8. Use a lambda function in Python to sort a list of tuples based on the second element of each tuple.**

# %%
tuples = [(1, 3), (2, 1), (4, 2)]
sorted_tuples = sorted(tuples, key=lambda x: x[1])

# %% [markdown]
# **9. Write a Python program that uses `map()` to convert a list of temperatures from Celsius to Fahrenheit.**

# %%
celsius = [0, 20, 30, 40]
fahrenheit = list(map(lambda c: (c * 9/5) + 32, celsius))

# %% [markdown]
# **10. Create a Python program that uses `filter()` to remove all the vowels from a given string.**

# %%
def remove_vowels(s):
    return ''.join(filter(lambda x: x.lower() not in 'aeiou', s))

# %% [markdown]
# ![Screenshot 2025-07-27 145740.png](data:image/png;base64,...)

# %%
# Given data
orders = [
    [34587, "Learning Python, Mark Lutz", 4, 40.95],
    [98762, "Programming Python, Mark Lutz", 5, 56.80],
    [77226, "Head First Python, Paul Barry", 3, 32.95],
    [88112, "Einführung in Python3, Bernd Klein", 3, 24.99]
]

# Processing orders
def process_orders(order_list):
    result = []
    for order in order_list:
        order_num, title, quantity, price = order
        total = quantity * price
        if total < 100:
            total += 10  # Add surcharge
        result.append((order_num, round(total, 2)))
    return result

# Output the processed result
processed_orders = process_orders(orders)
print(processed_orders)
# Out:
# [(34587, 163.8), (98762, 284.0), (77226, 108.85), (88112, 84.97)]
